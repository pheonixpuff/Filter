# %%
import numpy as np
from scipy import signal
from scipy import misc
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
from skimage import io, color
from skimage import exposure
from ast import literal_eval

img = io.imread('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQmoqjvVmTct5vURIpUFZHq9C3mNukmj6BNeez-38dJ1gAU6VQU8w')    # Load the image
img = color.rgb2gray(img)       # Convert the image to grayscale (1 channel)

# %%
img.shape
# Out:
# (194, 260)

# %%
type(img[0][0])  # h,w
# Out:
# numpy.float64

# %%
# kernel = np.array([[1/9,1/9,1/9],[1/9,1/9,1/9],[1/9,1/9,1/9]]) # blurr
# kernel = np.array([[-1,-1,-1],[2,2,2],[-1,-1,-1]]) # horizontal edge detection
kernel = np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]]) # edge detection\m

# filter=tf.Variable(kernel)
# input= tf.reshape(img, [1, 900, 1200, 1])
# filter1 = tf.reshape(filter, [3, 3, 1, 1])
# filter1=tf.cast(filter1,tf.float64)
# ###
# input = tf.placeholder(tf.float64)
# filter = tf.placeholder(tf.float64)
# i = img.reshape(1, 900, 1200, 1)
# f = kernel.reshape(3, 3, 1, 1)
# # f = tf.cast(filter1, tf.float64)
# print(kernel)

############
i = img.reshape(1, 194, 260, 1)
f = kernel.reshape(3, 3, 1, 1)
input =tf.constant(i,dtype=tf.float32)
filter=tf.constant(f,dtype=tf.float32)

# %%
op2 = tf.squeeze(tf.nn.conv2d(input, filter, strides=[1, 1, 1, 1], padding='SAME'))
#res=op2.eval()
# init = tf.global_variables_initializer()
# with tf.Session() as sess:
#     sess.run(init)
#     im=sess.run(op2)


# with tf.Session() as session:
#     init = tf.global_variables_initializer()
#     session.run(init)
# #     define inputs
#     feed_dict = {input: i, filter: f}
#     # pass data in and run the computation graph in a session
#     output = session.run(op2, feed_dict=feed_dict)

# with tf.Session() as sess:
#     sess.run(tf.global_variables_initializer())
#     feed_dict = {input: i, filter: f}
#     label_numpy = op2.eval()


with tf.Session() as sess:
    bla=sess.run(op2)

# %%
plt.imshow(bla, cmap=plt.cm.gray)
# plt.imshow(img, cmap=plt.cm.gray)

# plt.axis('off')
# plt.show()

# %%
plt.imshow(img, cmap=plt.cm.gray)
